# %%
#Import necessary packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML,Image
from pathlib import Path
import sklearn
import sklearn.model_selection
import sklearn.feature_selection
from os import listdir
# %matplotlib inline
from sklearn.decomposition import PCA

# %%
#Setting up the environment and importing the necessary data

sns.set_style("darkgrid")
data_dir=Path("data")
tissue_dir=Path("tissue-specific")

#!mkdir data && cp merged_meta.tsv data #Needed after cloning repo
manifest={
    "data":"All_Tissue_Site_Details.combined.reads.gct",
    "sample_meta":"GTEx_v7_Annotations_SampleAttributesDS.txt",
    "subject_meta":"GTEx_v7_Annotations_SubjectPhenotypesDS.txt",
    "merged_meta":"merged_meta.tsv"}

meta=pd.read_csv(manifest['merged_meta'],sep="\t",dtype={'SMUBRID':object,'SEX':object,'DTHHRDY':object})
meta
# Out:
#                          SAMPID  SMATSSCR SMCENTER  \
# 0      GTEX-1117F-0226-SM-5GZZ7       0.0       B1
# 1      GTEX-111CU-1826-SM-5GZYN       0.0       B1
# 2      GTEX-111FC-0226-SM-5N9B8       2.0       B1
# 3      GTEX-111VG-2326-SM-5N9BK       1.0       B1
# 4      GTEX-111YS-2426-SM-5GZZQ       0.0       B1
# 5      GTEX-1122O-2026-SM-5NQ91       0.0       B1
# 6      GTEX-1128S-2126-SM-5H12U       0.0       B1
# 7      GTEX-113IC-0226-SM-5HL5C       0.0       B1
# 8      GTEX-117YX-2226-SM-5EGJJ       0.0       B1
# 9      GTEX-11DXW-0326-SM-5H11W       1.0       C1
# 10     GTEX-11DXX-2326-SM-5Q5A2       1.0       B1
# 11     GTEX-11DZ1-0226-SM-5A5KF       1.0       C1
# 12     GTEX-11EI6-0226-SM-5EQ64       0.0       C1
# 13     GTEX-11EM3-2326-SM-5H12B       1.0       B1
# 14     GTEX-11EMC-2826-SM-5PNY6       0.0       B1
# 15     GTEX-11EQ8-0226-SM-5EQ5G       1.0       C1
# 16     GTEX-11EQ9-2526-SM-5HL66       0.0       B1
# 17     GTEX-11GS4-2626-SM-5A5LD       1.0       B1
# 18     GTEX-11GSO-2326-SM-5A5LX       1.0       B1
# 19     GTEX-11H98-0226-SM-5NQ89       1.0       B1
# 20     GTEX-11I78-2626-SM-5Q5AI       0.0       B1
# 21     GTEX-11LCK-1126-SM-5A5KC       0.0       B1
# 22     GTEX-11O72-0226-SM-59869       0.0       C1
# 23     GTEX-11OF3-2426-SM-5Q5AS       1.0       B1
# 24     GTEX-11ONC-2526-SM-5986W       0.0       B1
# 25     GTEX-11P7K-2026-SM-5GU74       0.0       B1
# 26     GTEX-11P81-2426-SM-5GU65       0.0       B1
# 27     GTEX-11P82-1726-SM-5Q5AT       0.0       B1
# 28     GTEX-11PRG-0626-SM-5BC56       0.0       C1
# 29     GTEX-11TT1-2426-SM-5EQMK       0.0       B1
# ...                         ...       ...      ...
# 11658   GTEX-ZF29-0006-SM-4WKGQ       NaN       B1
# 11659   GTEX-ZF2S-0006-SM-4WKHF       NaN       B1
# 11660   GTEX-ZF3C-0005-SM-4WWAR       NaN       C1
# 11661   GTEX-ZG7Y-0006-SM-4WWEA       NaN       B1
# 11662   GTEX-ZGAY-0006-SM-4WWAQ       NaN       C1
# 11663   GTEX-ZLV1-0005-SM-4WWAP       NaN       B1
# 11664   GTEX-ZP4G-0006-SM-4WWE6       NaN       B1
# 11665   GTEX-ZPCL-0006-SM-4WWAS       NaN       B1
# 11666   GTEX-ZPIC-0005-SM-4WWEB       NaN       B1
# 11667   GTEX-ZPU1-0006-SM-4WWAT       NaN       B1
# 11668   GTEX-ZQG8-0005-SM-4YCEH       NaN       B1
# 11669   GTEX-ZQUD-0005-SM-4YCE5       NaN       B1
# 11670   GTEX-ZT9W-0005-SM-4YCEG       NaN       B1
# 11671   GTEX-ZTPG-0006-SM-4YCFG       NaN       B1
# 11672   GTEX-ZTSS-0005-SM-4YCDR       NaN       B1
# 11673   GTEX-ZTTD-0006-SM-51MSJ       NaN       C1
# 11674   GTEX-ZTX8-0006-SM-4YCE4       NaN       B1
# 11675   GTEX-ZUA1-0005-SM-4YCEV       NaN       C1
# 11676   GTEX-ZV68-0006-SM-4YCEJ       NaN       B1
# 11677   GTEX-ZV7C-0005-SM-57WDL       NaN       B1
# 11678   GTEX-ZVE2-0006-SM-51MRW       NaN       C1
# 11679   GTEX-ZVP2-0005-SM-51MRK       NaN       B1
# 11680   GTEX-ZVT2-0005-SM-57WBW       NaN       B1
# 11681   GTEX-ZVT3-0006-SM-51MT9       NaN       C1
# 11682   GTEX-ZVT4-0006-SM-57WB8       NaN       C1
# 11683   GTEX-ZVTK-0006-SM-57WBK       NaN       C1
# 11684   GTEX-ZVZP-0006-SM-51MSW       NaN       B1
# 11685   GTEX-ZVZQ-0006-SM-51MR8       NaN       C1
# 11686   GTEX-ZXES-0005-SM-57WCB       NaN       B1
# 11687   GTEX-ZXG5-0005-SM-57WCN       NaN       B1
#
#                                                 SMPTHNTS  SMRIN  \
# 0           2 pieces, ~15% vessel stroma, rep delineated    6.8
# 1      2 pieces, small portion of nerve (<10% of one ...    7.5
# 2      2 pieces, larger piece is 30% fibrovascular ti...    7.3
# 3                                               2 pieces    7.7
# 4                               3 small irregular pieces    6.6
# 5                                               2 pieces    6.3
# 6                                               2 pieces    6.5
# 7      2 pieces, 40-50% adipose tissue (delineated), ...    6.7
# 8                    2 pieces, 1 with 20% fibrous tissue    7.4
# 9      2 pieces, ~20 and 30% fibrous with few larger ...    7.3
# 10     2 pieces, few large vessels and nerve, central...    8.1
# 11                   2 pieces; 10% fibrovascular content    6.4
# 12     2 pieces, ~10-15% fascia/fibrous tissue, rep. ...    6.8
# 13     2 pieces, one is ~10% fibrous with few sweat g...    7.1
# 14     2 pieces, ~20% fascia/fibrous tissue, rep deli...    8.1
# 15                                              2 pieces    6.0
# 16                    2 pieces~10% fibrous tissue/fascia    6.9
# 17     2 pieces, includes small portion of nerve, det...    7.0
# 18                                              2 pieces    7.9
# 19                       3 pieces; 20% fibrous component    6.7
# 20      2 pieces, ~5% fascia/vascular tissue, delineated    6.3
# 21       2 pieces ~5% fibrous/fascial tissue, delineated    7.0
# 22     2 pieces; 1 piece is 60% fibrous, also  contai...    6.4
# 23                                              2 pieces    6.3
# 24               2 pieces; 20% fibrous tissue in 1 piece    7.5
# 25                         2 pieces; 20% fibrous content    7.7
# 11682   GTEX-ZVT4  2.0  50-59      3.0
# 11683   GTEX-ZVTK  1.0  20-29      1.0
# 11684   GTEX-ZVZP  1.0  50-59      0.0
# 11685   GTEX-ZVZQ  2.0  60-69      1.0
# 11686   GTEX-ZXES  2.0  30-39      0.0
# 11687   GTEX-ZXG5  1.0  60-69      3.0
#
# [11688 rows x 67 columns]

# %%
meta=meta[~(meta['AGE'].isnull())] # removes all samples without age

# %%
counts=pd.DataFrame(meta['SMTS'].value_counts())
display(counts)
# Out:
#                  SMTS
# Skin             1202
# Esophagus        1021
# Blood Vessel      913
# Adipose Tissue    797
# Heart             600
# Muscle            564
# Blood             537
# Colon             507
# Thyroid           446
# Lung              427
# Nerve             414
# Brain             331
# Breast            290
# Stomach           261
# Testis            259
# Pancreas          248
# Adrenal Gland     190
# Pituitary         183
# Liver             175
# Spleen            162
# Prostate          152
# Small Intestine   137
# Ovary             133
# Vagina            115
# Uterus            111
# Salivary Gland     97
# Kidney             45
# Cervix Uteri       11
# Bladder            11
# Fallopian Tube      7

# %%
df=meta[meta['SMTS'].isin(counts[counts['SMTS']>200].index)]
df=pd.crosstab(index=df['SMTS'],columns=df['AGE'])
display(df)
Tissue_list=df.index
# Out:
# AGE             20-29  30-39  40-49  50-59  60-69  70-79
# SMTS
# Adipose Tissue     57     66    131    273    245     25
# Blood              50     46    103    169    163      6
# Blood Vessel       75     75    160    310    273     20
# Brain              12      8     36    112    152     11
# Breast             26     32     53     88     81     10
# Colon              45     48     95    164    140     15
# Esophagus         102     91    191    356    258     23
# Heart              33     29     95    220    205     18
# Lung               27     30     76    145    139     10
# Muscle             46     45     88    188    179     18
# Nerve              33     33     70    130    133     15
# Pancreas           20     21     53     95     57      2
# Skin               98     94    200    398    377     35
# Stomach            33     27     52     93     55      1
# Testis             25     25     38     90     75      6
# Thyroid            30     29     81    151    143     12

# %%
#SVM Method classification for tissues with more than 200 samples 
import random
infiles=listdir(tissue_dir)
def simpleExpressionFilter(counts,min_count):
        """accepts raw counts and a minimum sum count per gene across all samples
        return a boolean array of all genes, which can be applied to any transformed counts.
        True is associated with passing the test.
        """
        keep=np.sum(counts)>min_count
        filtered_counts=counts.loc[:,(keep)] # similar to how the boolean array would be used on any count matrix
        print("Post",filtered_counts.shape[1])
        return keep

accuracy=[]
for TISSUE in Tissue_list:
    cpm=pd.read_csv(tissue_dir/str(TISSUE+"_cpm.tsv"),sep="\t",index_col=0)
    #lcpm=pd.read_csv(tissue_dir/str(TISSUE+"_lcpm.tsv"),sep="\t",index_col=0)
    cdat=pd.read_csv(tissue_dir/str(TISSUE+"_c.tsv"),sep="\t",index_col=0)
    tissue_meta=meta[(meta['SMTS']==TISSUE)]
    cdat_train, cdat_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(cdat, tissue_meta['AGE'], test_size=.3, random_state=1234)
    cpm_train, cpm_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(cpm, tissue_meta['AGE'], test_size=.3, random_state=1234) # random state guarantees that the same split is made for a given tissue.
    sum(cpm_train.iloc[:,0]) # Confirms that the split is the same each time
    # Biased against samples with a smaller library size
    keep_expr=simpleExpressionFilter(cdat_train,10)
    cpm_train_expression_filter=cpm_train.loc[:,(keep_expr)]
    cpm_test_expression_filter=cpm_test.loc[:,(keep_expr)]
    selector=sklearn.feature_selection.VarianceThreshold(threshold=.1)
    selector.fit(cpm_train_expression_filter)
    var_keep=selector.get_support(indices=True)
    train_final=cpm_train_expression_filter.iloc[:,var_keep]
    test_final=cpm_test_expression_filter.iloc[:,var_keep]
    X=train_final.append(test_final)
    y=y_train.append(y_test)
    X=X.values
    y=y.values
    pca=PCA(n_components=len(y))
    X=pca.fit_transform(X)
    X.shape
    total_number=len(y)
    train_number=round(0.8*total_number)
    random_vals=random.sample(range(total_number+1), train_number)
    X_train=X[[i for i in range(0,total_number) if i in random_vals]]
    X_test=X[[i for i in range(0,total_number) if i not in random_vals]]
    y_train=y[[i for i in range(0,total_number) if i in random_vals]]
    y_test=y[[i for i in range(0,total_number) if i not in random_vals]]
    #['linear', 'rbf', 'poly', 'sigmoid']
    init=sklearn.svm.classes.SVC(kernel='linear')
    classifier=init.fit(X_train, y_train)
    ev=classifier.predict(X_test)
    ac=0
    for i in range (0,len(y_test)):
        if y_test[i]==ev[i]:
            a=0
        else:
            a=1
        ac=ac+a
    ac=1-ac/len(y_test)
    accuracy.append(ac)
    print('The accuracy for ')
    print(TISSUE)
    print(' is: ')
    print(accuracy)
# Out:
# Post 46532
# The accuracy for
# Adipose Tissue
#  is:
# [0.35]
# Post 43553
# The accuracy for
# Blood
#  is:
# [0.35, 0.2314814814814815]
# Post 46599
# The accuracy for
# Blood Vessel
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522]
# Post 44726
# The accuracy for
# Brain
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657]
# Post 43752
# The accuracy for
# Breast
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743]
# Post 44995
# The accuracy for
# Colon
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056]
# Post 47244
# The accuracy for
# Esophagus
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147]
# Post 44064
# The accuracy for
# Heart
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677]
# Post 44844
# The accuracy for
# Lung
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954]
# Post 43121
# The accuracy for
# Muscle
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954, 0.3157894736842105]
# Post 45190
# The accuracy for
# Nerve
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954, 0.3157894736842105, 0.30952380952380953]
# Post 39900
# The accuracy for
# Pancreas
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954, 0.3157894736842105, 0.30952380952380953, 0.27450980392156865]
# Post 48352
# The accuracy for
# Skin
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954, 0.3157894736842105, 0.30952380952380953, 0.27450980392156865, 0.3526970954356846]
# Post 41113
# The accuracy for
# Stomach
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954, 0.3157894736842105, 0.30952380952380953, 0.27450980392156865, 0.3526970954356846, 0.1923076923076923]
# Post 48989
# The accuracy for
# Testis
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954, 0.3157894736842105, 0.30952380952380953, 0.27450980392156865, 0.3526970954356846, 0.1923076923076923, 0.3207547169811321]
# Post 45160
# The accuracy for
# Thyroid
#  is:
# [0.35, 0.2314814814814815, 0.4347826086956522, 0.4029850746268657, 0.22033898305084743, 0.38235294117647056, 0.4341463414634147, 0.4132231404958677, 0.2093023255813954, 0.3157894736842105, 0.30952380952380953, 0.27450980392156865, 0.3526970954356846, 0.1923076923076923, 0.3207547169811321, 0.3222222222222222]

# %%
# KNN method for tissue with more than 200 samples
import random
#from sklearn.neighbors import KNeighborstClassifier
infiles=listdir(tissue_dir)
def simpleExpressionFilter(counts,min_count):
        """accepts raw counts and a minimum sum count per gene across all samples
        return a boolean array of all genes, which can be applied to any transformed counts.
        True is associated with passing the test.
        """
        keep=np.sum(counts)>min_count
        filtered_counts=counts.loc[:,(keep)] # similar to how the boolean array would be used on any count matrix
        print("Post",filtered_counts.shape[1])
        return keep

accuracy_knn=[]
for TISSUE in Tissue_list:
    cpm=pd.read_csv(tissue_dir/str(TISSUE+"_cpm.tsv"),sep="\t",index_col=0)
    #lcpm=pd.read_csv(tissue_dir/str(TISSUE+"_lcpm.tsv"),sep="\t",index_col=0)
    cdat=pd.read_csv(tissue_dir/str(TISSUE+"_c.tsv"),sep="\t",index_col=0)
    tissue_meta=meta[(meta['SMTS']==TISSUE)]
    cdat_train, cdat_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(cdat, tissue_meta['AGE'], test_size=.3, random_state=1234)
    cpm_train, cpm_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(cpm, tissue_meta['AGE'], test_size=.3, random_state=1234) # random state guarantees that the same split is made for a given tissue.
    sum(cpm_train.iloc[:,0]) # Confirms that the split is the same each time
    # Biased against samples with a smaller library size
    keep_expr=simpleExpressionFilter(cdat_train,10)
    cpm_train_expression_filter=cpm_train.loc[:,(keep_expr)]
    cpm_test_expression_filter=cpm_test.loc[:,(keep_expr)]
    selector=sklearn.feature_selection.VarianceThreshold(threshold=.1)
    selector.fit(cpm_train_expression_filter)
    var_keep=selector.get_support(indices=True)
    train_final=cpm_train_expression_filter.iloc[:,var_keep]
    test_final=cpm_test_expression_filter.iloc[:,var_keep]
    X=train_final.append(test_final)
    y=y_train.append(y_test)
    X=X.values
    y=y.values
    pca=PCA(n_components=len(y))
    X=pca.fit_transform(X)
    X.shape
    total_number=len(y)
    train_number=round(0.8*total_number)
    random_vals=random.sample(range(total_number+1), train_number)
    X_train=X[[i for i in range(0,total_number) if i in random_vals]]
    X_test=X[[i for i in range(0,total_number) if i not in random_vals]]
    y_train=y[[i for i in range(0,total_number) if i in random_vals]]
    y_test=y[[i for i in range(0,total_number) if i not in random_vals]]
    #['linear', 'rbf', 'poly', 'sigmoid']
    init=sklearn.neighbors.KNeighborsClassifier(n_neighbors=6)
    classifier=init.fit(X_train, y_train)
    ev=classifier.predict(X_test)
    ac=0
    for i in range (0,len(y_test)):
        if y_test[i]==ev[i]:
            a=0
        else:
            a=1
        ac=ac+a
    ac=1-ac/len(y_test)
    accuracy_knn.append(ac)
    print('The accuracy for ')
    print(TISSUE)
    print(' is: ')
    print(accuracy_knn)
# Out:
# Post 46532
# The accuracy for
# Adipose Tissue
#  is:
# [0.30625]
# Post 43553
# The accuracy for
# Blood
#  is:
# [0.30625, 0.25]
# Post 46599
# The accuracy for
# Blood Vessel
#  is:
# [0.30625, 0.25, 0.34239130434782605]
# Post 44726
# The accuracy for
# Brain
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945]
# Post 43752
# The accuracy for
# Breast
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164]
# Post 44995
# The accuracy for
# Colon
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337]
# Post 47244
# The accuracy for
# Esophagus
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176]
# Post 44064
# The accuracy for
# Heart
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946]
# Post 44844
# The accuracy for
# Lung
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974]
# Post 43121
# The accuracy for
# Muscle
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974, 0.3070175438596491]
# Post 45190
# The accuracy for
# Nerve
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974, 0.3070175438596491, 0.22619047619047616]
# Post 39900
# The accuracy for
# Pancreas
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974, 0.3070175438596491, 0.22619047619047616, 0.4117647058823529]
# Post 48352
# The accuracy for
# Skin
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974, 0.3070175438596491, 0.22619047619047616, 0.4117647058823529, 0.2655601659751037]
# Post 41113
# The accuracy for
# Stomach
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974, 0.3070175438596491, 0.22619047619047616, 0.4117647058823529, 0.2655601659751037, 0.3584905660377359]
# Post 48989
# The accuracy for
# Testis
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974, 0.3070175438596491, 0.22619047619047616, 0.4117647058823529, 0.2655601659751037, 0.3584905660377359, 0.2264150943396226]
# Post 45160
# The accuracy for
# Thyroid
#  is:
# [0.30625, 0.25, 0.34239130434782605, 0.43939393939393945, 0.18644067796610164, 0.33333333333333337, 0.30731707317073176, 0.31404958677685946, 0.36046511627906974, 0.3070175438596491, 0.22619047619047616, 0.4117647058823529, 0.2655601659751037, 0.3584905660377359, 0.2264150943396226, 0.3111111111111111]

# %%
accuracy
# Out:
# [0.35,
#  0.2314814814814815,
#  0.4347826086956522,
#  0.4029850746268657,
#  0.22033898305084743,
#  0.38235294117647056,
#  0.4341463414634147,
#  0.4132231404958677,
#  0.2093023255813954,
#  0.3157894736842105,
#  0.30952380952380953,
#  0.27450980392156865,
#  0.3526970954356846,
#  0.1923076923076923,
#  0.3207547169811321,
#  0.3222222222222222]

# %%
Tissue_list
# Out:
# Index(['Adipose Tissue', 'Blood', 'Blood Vessel', 'Brain', 'Breast', 'Colon',
#        'Esophagus', 'Heart', 'Lung', 'Muscle', 'Nerve', 'Pancreas', 'Skin',
#        'Stomach', 'Testis', 'Thyroid'],
#       dtype='object', name='SMTS')

# %%
sns.barplot(Tissue_list, accuracy)
plt.title('Accuracy of Different Tissues for SVM method')
plt.xlabel('Tissue Type')
plt.ylabel('Accuracy')
plt.xticks(rotation=30, ha='right')
plt.savefig('SVM_Accuracy.png')

# %%
sns.barplot(Tissue_list, accuracy_knn)
plt.title('Accuracy of Different Tissues for KNN method')
plt.xlabel('Tissue Type')
plt.ylabel('Accuracy')
plt.xticks(rotation=30, ha='right')
plt.savefig('KNN_Accuracy.png')

# %%
SVM_ACCURACY_FILE=pd.DataFrame(columns=['tissue', 'accuracy'])

# %%
SVM_ACCURACY_FILE['tissue']=Tissue_list

# %%
SVM_ACCURACY_FILE['tissue']=Tissue_list

# %%
SVM_ACCURACY_FILE.to_csv('SVM_ACCURACY_FILE.csv')

# %%
KNN_ACCURACY_FILE=pd.DataFrame(columns=['tissue', 'accuracy'])
KNN_ACCURACY_FILE['tissue']=Tissue_list
KNN_ACCURACY_FILE['accuracy']=accuracy_knn
KNN_ACCURACY_FILE.to_csv('KNN_ACCURACY_FILE.csv')
