# %% [markdown]
# ## Death DGE Results

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from pathlib import Path
from os import listdir

# %%
df=pd.read_csv("DGE_plots/DEATH/DGE_results.tsv",sep="\t",index_col=0)

# %%
df
# Out:
#             Unnamed: 0     logFC    AveExpr          t        P.Value  \
# 0      ENSG00000248187  2.499633  -2.429252  21.762745  1.334428e-102
# 1      ENSG00000177575  2.469073   5.335212  21.295669   1.909379e-98
# 2      ENSG00000096060  1.862116   7.925455  18.958145   7.100135e-79
# 3      ENSG00000236047 -1.810316  -2.717888 -18.410056   1.379141e-74
# 4      ENSG00000198570  2.022944  -3.340184  15.828339   5.883423e-56
# 5      ENSG00000270640 -1.827150  -0.939188 -15.784672   1.153979e-55
# 6      ENSG00000120088 -1.965601  -3.100976 -14.398850   8.955606e-47
# 7      ENSG00000188536 -2.176149   3.562175 -13.912373   7.763313e-44
# 8      ENSG00000264590 -1.617284  -5.344166 -13.813945   2.970660e-43
# 9      ENSG00000267653  2.098869  -1.108639  13.756837   6.444762e-43
# 10     ENSG00000196136  1.976250   5.428905  13.397273   7.881156e-41
# 11     ENSG00000269929  1.537672  -4.078040  12.969867   2.039542e-38
# 12     ENSG00000244734 -2.130071   5.389962 -12.644236   1.253029e-36
# 13     ENSG00000236279 -1.845182  -3.186177 -12.610627   1.905828e-36
# 14     ENSG00000169385  1.962306  -1.175690  12.571788   3.090105e-36
# 15     ENSG00000198547 -1.601588  -1.124692 -12.513915   6.332545e-36
# 16     ENSG00000155659  2.003651   3.691966  12.455751   1.298292e-35
# 17     ENSG00000173597  1.919218   0.447075  11.980876   4.047303e-33
# 18     ENSG00000182667 -1.718145   1.896025 -11.778586   4.379175e-32
# 19     ENSG00000111537 -1.742166  -4.676018 -11.766323   5.052987e-32
# 20     ENSG00000161681 -1.600189  -0.758394 -11.700393   1.088068e-31
# 21     ENSG00000225572 -1.618682  -4.015576 -11.551069   6.088304e-31
# 22     ENSG00000258469 -1.507705  -1.247175 -11.500333   1.087670e-30
# 23     ENSG00000183715 -1.790488  -1.521777 -11.418859   2.747671e-30
# 24     ENSG00000241112 -1.565768  -3.287628 -11.353687   5.740196e-30
# 25     ENSG00000206172 -2.043714   0.009606 -11.324001   8.018468e-30
# 26     ENSG00000262905 -1.451741  -2.765057 -11.273626   1.411226e-29
# 27     ENSG00000260799 -1.513321  -3.427220 -11.042676   1.826942e-28
# 28     ENSG00000182132 -1.660866  -2.036902 -10.944922   5.318907e-28
# 29     ENSG00000171388 -1.580138   1.119541 -10.927831   6.405589e-28
# ...                ...       ...        ...        ...            ...
# 28017  ENSG00000235001  0.392771  -3.052904   0.000000   1.000000e+00
# 28018  ENSG00000168757 -0.105838  -6.323191   0.000000   1.000000e+00
# 28019  ENSG00000234795 -0.151020  -6.136944   0.000000   1.000000e+00
# 28020  ENSG00000239893 -0.297500  -5.811021   0.000000   1.000000e+00
# 28021  ENSG00000232226 -0.357192  -5.908975   0.000000   1.000000e+00
# 28022  ENSG00000215414  0.165545  -3.071488   0.000000   1.000000e+00
# 28023  ENSG00000157828 -0.187119  -6.148439   0.000000   1.000000e+00
# 28024  ENSG00000237917  0.547079  -4.943903   0.000000   1.000000e+00
# 28025  ENSG00000211459 -0.239694   9.997577   0.000000   1.000000e+00
# 28026  ENSG00000210077 -0.007856  -4.478324   0.000000   1.000000e+00
# 28027  ENSG00000210082 -0.237680  12.871788   0.000000   1.000000e+00
# 28028  ENSG00000209082  0.295389  -2.262018   0.000000   1.000000e+00
# 28029  ENSG00000198888  0.074990  12.610461   0.000000   1.000000e+00
# 28030  ENSG00000210100  0.395453  -4.115337   0.000000   1.000000e+00
# 28031  ENSG00000210112 -0.040417  -4.507129   0.000000   1.000000e+00
# 28032  ENSG00000198763 -0.030757  12.770642   0.000000   1.000000e+00
# 28033  ENSG00000198804  0.471925  13.797385   0.000000   1.000000e+00
# 28034  ENSG00000210151  0.450719   1.447543   0.000000   1.000000e+00
# 28035  ENSG00000198712  0.102824  12.847140   0.000000   1.000000e+00
# 28036  ENSG00000228253 -0.032228  10.125795   0.000000   1.000000e+00
# 28037  ENSG00000198899 -0.040054  12.792252   0.000000   1.000000e+00
# 28038  ENSG00000198938 -0.177844  13.125614   0.000000   1.000000e+00
# 28039  ENSG00000210164  0.023132  -5.200261   0.000000   1.000000e+00
# 28040  ENSG00000198840 -0.124105  10.782673   0.000000   1.000000e+00
# 28041  ENSG00000212907  0.107376  10.377908   0.000000   1.000000e+00
# 28042  ENSG00000198886  0.086215  13.861057   0.000000   1.000000e+00
# 28043  ENSG00000210176  0.149390  -5.037948   0.000000   1.000000e+00
# 28044  ENSG00000198786  0.537521  11.828022   0.000000   1.000000e+00
# 28045  ENSG00000198727  0.061109  13.012836   0.000000   1.000000e+00
# 28046  ENSG00000210196  0.151107  -4.296913   0.000000   1.000000e+00
#
#           adj.P.Val             Gene       hgnc uniprot         name  \
# 0      3.742670e-98  ENSG00000248187        NaN     NaN          NaN
# 1      2.677617e-94  ENSG00000177575      CD163  Q86VB7  C163A_HUMAN
# 2      6.637916e-75  ENSG00000096060      FKBP5  Q13451  FKBP5_HUMAN
# 3      9.670191e-71  ENSG00000236047        NaN     NaN          NaN
# 4      3.300247e-52  ENSG00000198570        RD3  Q7Z3Z2    RD3_HUMAN
# 5      5.394276e-52  ENSG00000270640        NaN     NaN          NaN
# 6      3.588255e-43  ENSG00000120088      CRHR1     NaN          NaN
# 7      2.721721e-40  ENSG00000188536       HBA2  P69905    HBA_HUMAN
# 8      9.257567e-40  ENSG00000264590        NaN     NaN          NaN
# 9      1.807562e-39  ENSG00000267653        NaN     NaN          NaN
# 10     2.009480e-37  ENSG00000196136   SERPINA3  P01011   AACT_HUMAN
# 11     4.766919e-35  ENSG00000269929        NaN     NaN          NaN
# 12     2.703361e-33  ENSG00000244734        HBB  P68871    HBB_HUMAN
# 13     3.818054e-33  ENSG00000236279     CLEC2L  P0C7M8  CLC2L_HUMAN
# 14     5.777879e-33  ENSG00000169385     RNASE2  P10153  RNAS2_HUMAN
# 15     1.110056e-32  ENSG00000198547  C20orf203  Q8NBC4  CT203_HUMAN
# 16     2.141953e-32  ENSG00000155659      VSIG4     NaN          NaN
# 17     6.306373e-30  ENSG00000173597    SULT1B1  O43704  ST1B1_HUMAN
# 18     6.464354e-29  ENSG00000182667        NTM  Q9P121   NTRI_HUMAN
# 19     7.086056e-29  ENSG00000111537       IFNG  P01579   IFNG_HUMAN
# 20     1.453193e-28  ENSG00000161681     SHANK1  Q9Y566  SHAN1_HUMAN
# 21     7.761757e-28  ENSG00000225572        NaN     NaN          NaN
# 22     1.326343e-27  ENSG00000258469        NaN     NaN          NaN
# 23     3.210997e-27  ENSG00000183715      OPCML  Q14982   OPCM_HUMAN
# 24     6.439811e-27  ENSG00000241112        NaN     NaN          NaN
# 25     8.649768e-27  ENSG00000206172       HBA1  P69905    HBA_HUMAN
# 26     1.465950e-26  ENSG00000262905        NaN     NaN          NaN
# 27     1.830009e-25  ENSG00000260799        NaN     NaN          NaN
# 28     5.144117e-25  ENSG00000182132     KCNIP1  Q9NZI2  KCIP1_HUMAN
# 29     5.988585e-25  ENSG00000171388       APLN  Q9ULZ1   APEL_HUMAN
# ...             ...              ...        ...     ...          ...
# 28017  1.000000e+00  ENSG00000235001        NaN     NaN          NaN
# 28018  1.000000e+00  ENSG00000168757      TSPY2     NaN          NaN
# 28019  1.000000e+00  ENSG00000234795        NaN     NaN          NaN
# 28020  1.000000e+00  ENSG00000239893        NaN     NaN          NaN
# 28021  1.000000e+00  ENSG00000232226        NaN     NaN          NaN
# 28022  1.000000e+00  ENSG00000215414        NaN     NaN          NaN
# 28023  1.000000e+00  ENSG00000157828        NaN     NaN          NaN
# 28024  1.000000e+00  ENSG00000237917        NaN     NaN          NaN
# 28025  1.000000e+00  ENSG00000211459        NaN     NaN          NaN
# 28026  1.000000e+00  ENSG00000210077        NaN     NaN          NaN
# 28027  1.000000e+00  ENSG00000210082        NaN     NaN          NaN
# 28028  1.000000e+00  ENSG00000209082        NaN     NaN          NaN
# 28029  1.000000e+00  ENSG00000198888     MT-ND1  P03886   NU1M_HUMAN
# 28030  1.000000e+00  ENSG00000210100        NaN     NaN          NaN
# 28031  1.000000e+00  ENSG00000210112        NaN     NaN          NaN
# 28032  1.000000e+00  ENSG00000198763     MT-ND2  P03891   NU2M_HUMAN
# 28033  1.000000e+00  ENSG00000198804     MT-CO1  P00395   COX1_HUMAN
# 28034  1.000000e+00  ENSG00000210151        NaN     NaN          NaN
# 28035  1.000000e+00  ENSG00000198712     MT-CO2  P00403   COX2_HUMAN
# 28036  1.000000e+00  ENSG00000228253    MT-ATP8  P03928   ATP8_HUMAN
# 28037  1.000000e+00  ENSG00000198899    MT-ATP6  P00846   ATP6_HUMAN
# 28038  1.000000e+00  ENSG00000198938     MT-CO3  P00414   COX3_HUMAN
# 28039  1.000000e+00  ENSG00000210164        NaN     NaN          NaN
# 28040  1.000000e+00  ENSG00000198840     MT-ND3  P03897   NU3M_HUMAN
# 28041  1.000000e+00  ENSG00000212907    MT-ND4L  P03901  NU4LM_HUMAN
# 28042  1.000000e+00  ENSG00000198886     MT-ND4  P03905   NU4M_HUMAN
# 28043  1.000000e+00  ENSG00000210176        NaN     NaN          NaN
# 28044  1.000000e+00  ENSG00000198786     MT-ND5  P03915   NU5M_HUMAN
# 28045  1.000000e+00  ENSG00000198727     MT-CYB  P00156    CYB_HUMAN
# 28046  1.000000e+00  ENSG00000210196        NaN     NaN          NaN
#
#                                                     desc  \
# 0                                                    NaN
# 1      Scavenger receptor cysteine-rich type 1 protei...
# 2              Peptidyl-prolyl cis-trans isomerase FKBP5
# 3                                                    NaN
# 4                                            Protein RD3
# 5                                                    NaN
# 6                                                    NaN
# 7                               Hemoglobin subunit alpha
# 8                                                    NaN
# 9                                                    NaN
# 10                              Alpha-1-antichymotrypsin
# 11                                                   NaN
# 12                               Hemoglobin subunit beta
# 13                C-type lectin domain family 2 member L
# 14                            Non-secretory ribonuclease
# 15                     Uncharacterized protein C20orf203
# 16                                                   NaN
# 17         Sulfotransferase family cytosolic 1B member 1
# 18                                           Neurotrimin
# 19                                      Interferon gamma
# 20     SH3 and multiple ankyrin repeat domains protein 1
# 21                                                   NaN
# 22                                                   NaN
# 23         Opioid-binding protein/cell adhesion molecule
# 24                                                   NaN
# 25                              Hemoglobin subunit alpha
# 26                                                   NaN
# 27                                                   NaN
# 28                      Kv channel-interacting protein 1
# 29                                                Apelin
# ...                                                  ...
# 28017                                                NaN
# 28018                                                NaN
# 28019                                                NaN
# 28020                                                NaN
# 28021                                                NaN
# 28022                                                NaN
# 28023                                                NaN
# 28024                                                NaN
# 28025                                                NaN
# 28026                                                NaN
# 28027                                                NaN
# 28028                                                NaN
# 28029             NADH-ubiquinone oxidoreductase chain 1
# 28030                                                NaN
# 28031                                                NaN
# 28032             NADH-ubiquinone oxidoreductase chain 2
# 28033                     Cytochrome c oxidase subunit 1
# 28034                                                NaN
# 28035                     Cytochrome c oxidase subunit 2
# 28036                             ATP synthase protein 8
# 28037                             ATP synthase subunit a
# 28038                     Cytochrome c oxidase subunit 3
# 28039                                                NaN
# 28040             NADH-ubiquinone oxidoreductase chain 3
# 28041            NADH-ubiquinone oxidoreductase chain 4L
# 28042             NADH-ubiquinone oxidoreductase chain 4
# 28043                                                NaN
# 28044             NADH-ubiquinone oxidoreductase chain 5
# 28045                                       Cytochrome b
# 28046                                                NaN
#
#                                                      sub  \
# 0                                                    NaN
# 1                               Secreted-->Cell membrane
# 2                                    Cytoplasm-->Nucleus
# 3                                                    NaN
# 4                                                   None
# 5                                                    NaN
# 6                                                    NaN
# 7                                                   None
# 8                                                    NaN
# 9                                                    NaN
# 10                                              Secreted
# 11                                                   NaN
# 12                                                  None
# 13                                              Membrane
# 14                        Lysosome-->Cytoplasmic granule
# 15                                             Cytoplasm
# 16                                                   NaN
# 17                                             Cytoplasm
# 18                                         Cell membrane
# 19                                              Secreted
# 20     Cytoplasm-->Cell junction-->Synapse-->Postsyna...
# 21                                                   NaN
# 22                                                   NaN
# 23                                         Cell membrane
# 24                                                   NaN
# 25                                                  None
# 26                                                   NaN
# 27                                                   NaN
# 28     Cell membrane-->Cytoplasm-->Cell projection-->...
# 29                        Secreted-->Extracellular space
# ...                                                  ...
# 28017                                                NaN
# 28018                                                NaN
# 28019                                                NaN
# 28020                                                NaN
# 28021                                                NaN
# 28022                                                NaN
# 28023                                                NaN
# 28024                                                NaN
# 28025                                                NaN
# 28026                                                NaN
# 28027                                                NaN
# 28028                                                NaN
# 28029                       Mitochondrion inner membrane
# 28030                                                NaN
# 28031                                                NaN
# 28032                       Mitochondrion inner membrane
# 28033                       Mitochondrion inner membrane
# 28034                                                NaN
# 28035                       Mitochondrion inner membrane
# 28036                             Mitochondrion membrane
# 28037                       Mitochondrion inner membrane
# 28038                       Mitochondrion inner membrane
# 28039                                                NaN
# 28040                             Mitochondrion membrane
# 28041                             Mitochondrion membrane
# 28042                             Mitochondrion membrane
# 28043                                                NaN
# 28044                       Mitochondrion inner membrane
# 28045                       Mitochondrion inner membrane
# 28046                                                NaN
#
#                                   topology  \
# 0                                      NaN
# 1      Single-pass type I membrane protein
# 2                                     None
# 3                                      NaN
# 4                                     None
# 5                                      NaN
# 6                                      NaN
# 7                                     None
# 8                                      NaN
# 9                                      NaN
# 10                                    None
# 11                                     NaN
# 12                                    None
# 13            Single-pass membrane protein
# 14                                    None
# 15                                    None
# 16                                     NaN
# 17                                    None
# 18                Lipid-anchor, GPI-anchor
# 19                                    None
# 20                                    None
# 21                                     NaN
# 22                                     NaN
# 23                Lipid-anchor, GPI-anchor
# 24                                     NaN
# 25                                    None
# 26                                     NaN
# 27                                     NaN
# 28             Peripheral membrane protein
# 29                                    None
# ...                                    ...
# 28017                                  NaN
# 28018                                  NaN
# 28019                                  NaN
# 28020                                  NaN
# 28021                                  NaN
# 28022                                  NaN
# 28023                                  NaN
# 28024                                  NaN
# 28025                                  NaN
# 28026                                  NaN
# 28027                                  NaN
# 28028                                  NaN
# 28029          Multi-pass membrane protein
# 28030                                  NaN
# 28031                                  NaN
# 28032          Multi-pass membrane protein
# 28033          Multi-pass membrane protein
# 28034                                  NaN
# 28035          Multi-pass membrane protein
# 28036         Single-pass membrane protein
# 28037          Multi-pass membrane protein
# 28038          Multi-pass membrane protein
# 28039                                  NaN
# 28040          Multi-pass membrane protein
# 28041          Multi-pass membrane protein
# 28042          Multi-pass membrane protein
# 28043                                  NaN
# 28044          Multi-pass membrane protein
# 28045          Multi-pass membrane protein
# 28046                                  NaN
#
#                                                     func
# 0                                                    NaN
# 1      Acute phase-regulated receptor involved in cle...
# 2      Immunophilin protein with PPIase and co-chaper...
# 3                                                    NaN
# 4                                                   None
# 5                                                    NaN
# 6                                                    NaN
# 7      Involved in oxygen transport from the lung to ...
# 8                                                    NaN
# 9                                                    NaN
# 10     Although its physiological function is unclear...
# 11                                                   NaN
# 12     Involved in oxygen transport from the lung to ...
# 13                                                  None
# 14     This is a non-secretory ribonuclease. It is a ...
# 15                                                  None
# 16                                                   NaN
# 17     Sulfotransferase that utilizes 3'-phospho-5'-a...
# 18                        Neural cell adhesion molecule.
# 19     Produced by lymphocytes activated by specific ...
# 20     Seems to be an adapter protein in the postsyna...
# 21                                                   NaN
# 22                                                   NaN
# 23     Binds opioids in the presence of acidic lipids...
# 24                                                   NaN
# 25     Involved in oxygen transport from the lung to ...
# 26                                                   NaN
# 27                                                   NaN
# 28     Regulatory subunit of Kv4/D (Shal)-type voltag...
# 29     Endogenous ligand for the apelin receptor (APL...
# ...                                                  ...
# 28017                                                NaN
# 28018                                                NaN
# 28019                                                NaN
# 28020                                                NaN
# 28021                                                NaN
# 28022                                                NaN
# 28023                                                NaN
# 28024                                                NaN
# 28025                                                NaN
# 28026                                                NaN
# 28027                                                NaN
# 28028                                                NaN
# 28029  Core subunit of the mitochondrial membrane res...
# 28030                                                NaN
# 28031                                                NaN
# 28032  Core subunit of the mitochondrial membrane res...
# 28033  Cytochrome c oxidase is the component of the r...
# 28034                                                NaN
# 28035  Cytochrome c oxidase is the component of the r...
# 28036  Mitochondrial membrane ATP synthase (F(1)F(0) ...
# 28037  Mitochondrial membrane ATP synthase (F(1)F(0) ...
# 28038  Subunits I, II and III form the functional cor...
# 28039                                                NaN
# 28040  Core subunit of the mitochondrial membrane res...
# 28041  Core subunit of the mitochondrial membrane res...
# 28042  Core subunit of the mitochondrial membrane res...
# 28043                                                NaN
# 28044  Core subunit of the mitochondrial membrane res...
# 28045  Component of the ubiquinol-cytochrome c reduct...
# 28046                                                NaN
#
# [28047 rows x 14 columns]
