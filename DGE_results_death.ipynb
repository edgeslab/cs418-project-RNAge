# %% [markdown]
# ## Death DGE Results

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
from pathlib import Path
from os import listdir

# %%
df=pd.read_csv("DGE_plots/DEATH/DGE_results.tsv",sep="\t",index_col=0)

# %%
df.loc[:,["adj.P.Val","hgnc"]]
# Out:
#                     adj.P.Val       hgnc
# ENSG00000248187  3.742670e-98        NaN
# ENSG00000177575  2.677617e-94      CD163
# ENSG00000096060  6.637916e-75      FKBP5
# ENSG00000236047  9.670191e-71        NaN
# ENSG00000198570  3.300247e-52        RD3
# ENSG00000270640  5.394276e-52        NaN
# ENSG00000120088  3.588255e-43      CRHR1
# ENSG00000188536  2.721721e-40       HBA2
# ENSG00000264590  9.257567e-40        NaN
# ENSG00000267653  1.807562e-39        NaN
# ENSG00000196136  2.009480e-37   SERPINA3
# ENSG00000269929  4.766919e-35        NaN
# ENSG00000244734  2.703361e-33        HBB
# ENSG00000236279  3.818054e-33     CLEC2L
# ENSG00000169385  5.777879e-33     RNASE2
# ENSG00000198547  1.110056e-32  C20orf203
# ENSG00000155659  2.141953e-32      VSIG4
# ENSG00000173597  6.306373e-30    SULT1B1
# ENSG00000182667  6.464354e-29        NTM
# ENSG00000111537  7.086056e-29       IFNG
# ENSG00000161681  1.453193e-28     SHANK1
# ENSG00000225572  7.761757e-28        NaN
# ENSG00000258469  1.326343e-27        NaN
# ENSG00000183715  3.210997e-27      OPCML
# ENSG00000241112  6.439811e-27        NaN
# ENSG00000206172  8.649768e-27       HBA1
# ENSG00000262905  1.465950e-26        NaN
# ENSG00000260799  1.830009e-25        NaN
# ENSG00000182132  5.144117e-25     KCNIP1
# ENSG00000171388  5.988585e-25       APLN
# ...                       ...        ...
# ENSG00000235001  1.000000e+00        NaN
# ENSG00000168757  1.000000e+00      TSPY2
# ENSG00000234795  1.000000e+00        NaN
# ENSG00000239893  1.000000e+00        NaN
# ENSG00000232226  1.000000e+00        NaN
# ENSG00000215414  1.000000e+00        NaN
# ENSG00000157828  1.000000e+00        NaN
# ENSG00000237917  1.000000e+00        NaN
# ENSG00000211459  1.000000e+00        NaN
# ENSG00000210077  1.000000e+00        NaN
# ENSG00000210082  1.000000e+00        NaN
# ENSG00000209082  1.000000e+00        NaN
# ENSG00000198888  1.000000e+00     MT-ND1
# ENSG00000210100  1.000000e+00        NaN
# ENSG00000210112  1.000000e+00        NaN
# ENSG00000198763  1.000000e+00     MT-ND2
# ENSG00000198804  1.000000e+00     MT-CO1
# ENSG00000210151  1.000000e+00        NaN
# ENSG00000198712  1.000000e+00     MT-CO2
# ENSG00000228253  1.000000e+00    MT-ATP8
# ENSG00000198899  1.000000e+00    MT-ATP6
# ENSG00000198938  1.000000e+00     MT-CO3
# ENSG00000210164  1.000000e+00        NaN
# ENSG00000198840  1.000000e+00     MT-ND3
# ENSG00000212907  1.000000e+00    MT-ND4L
# ENSG00000198886  1.000000e+00     MT-ND4
# ENSG00000210176  1.000000e+00        NaN
# ENSG00000198786  1.000000e+00     MT-ND5
# ENSG00000198727  1.000000e+00     MT-CYB
# ENSG00000210196  1.000000e+00        NaN
#
# [28047 rows x 2 columns]
